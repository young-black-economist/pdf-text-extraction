# %%
## Import libraries ##
# Read pdfs
from PyPDF2 import PdfWriter, PdfReader
# Analyze
from pdfminer.high_level import extract_pages, extract_text
from pdfminer.layout import LTFigure
# Extract images
from PIL import Image
from pdf2image import convert_from_path
# OCR
import pytesseract 
# Remove extra files
import os
import json

# %%
# Crop the image in the PDF files
def cut_pix(bite, canvas):
    # Find coordinates to of images
    [pix_left, pix_top, pix_right, pix_bottom] = [bite.x0,bite.y0,bite.x1,bite.y1] 
    # Crop the coordinates
    canvas.mediabox.lower_left = (pix_left, pix_bottom)
    canvas.mediabox.upper_right = (pix_right, pix_top)
    # Put cropped image on new PDF
    cut_writer = PdfWriter()
    cut_writer.add_page(canvas)
    # Save this to a new file
    with open('cut_pix.pdf', 'wb') as cut_pdf_file:
        cut_writer.write(cut_pdf_file)

# Change PDF to PNGs
def pdf2png(in_file,):
    pixs = convert_from_path(in_file, poppler_path=r'C:\Release-23.11.0-0\poppler-23.11.0\Library\bin')
    pix = pixs[0]
    out_file = 'PDF_pix.png'
    pix.save(out_file, 'PNG')

# Use OCR to decipher text
def png2text(pix_path):
    img = Image.open(pix_path)
    # Extract text
    text = pytesseract.image_to_string(img)
    return text

# %%
# Find the PDF
pdf_location = 'B-TV-BC-YB-2003-04_5-7.pdf'
# Create pdf file and reader objects
pdf_attach = open(pdf_location, 'rb')
pdfread = PdfReader(pdf_attach)

# %%
# Create the dictionary to extract text from each image
text_in_canvas = {}

# Extract the pages from the PDF
for scroll_num, scroll in enumerate(extract_pages(pdf_location)):

    # Create variables
    canvas = pdfread.pages[scroll_num]
    scroll_text = []
    line_format = []
    text_in_pixs = []
    scroll_content = []
    
    # Find all the elements
    scroll_bite = [(bite.y1, bite) for bite in scroll._objs]
    # Sort
    scroll_bite.sort(key=lambda a: a[0], reverse=True)


    # Find elements in a page
    for i,component in enumerate(scroll_bite):
        # Extract
        bite = component[1]
        # Loop through pages
        if isinstance(bite, LTFigure):
                # Use function to crop the image from PDF
            cut_pix(bite, canvas)
                # Use function to convert the pdf to image
            pdf2png('cut_pix.pdf')
                # Use function to pull text from image
            pix_text = png2text('PDF_pix.png')
            text_in_pixs.append(pix_text)
            scroll_content.append(pix_text)
                # Add a placeholder in the text and format lists
            scroll_text.append('pix')
            line_format.append('pix')
                # Update the flag for image detection
          


    # Create dictionary key
    dctkey = 'Page_'+str(scroll_num)
    # Add the list to keys
    text_in_canvas[dctkey]= [scroll_text, line_format, text_in_pixs, scroll_content]

# %%
# Close the pdf file object
pdf_attach.close()

# %%
# Remove extra files
os.remove('cut_pix.pdf')
os.remove('PDF_pix.png')

# %%
result = ''.join(text_in_canvas['Page_0'][3])
print(result)
# Out:
# Directory of TV Stations in the United States
#
# Alabama
#
# Anniston
#
# DMA No. 51; see Birmingham (Anniston,
# Tuscaloosa), AL market
#
# WUSU-TV—ch 40, 724 kw vis, 93.9 kw aur, 880/243g, TL; N33 39 30
# Was 48 56, (CP: 9,000 kw vis, ant 1,299V571g, TL: N33 36 24 Wa6
# 25 03). On air date: Oct 26, 1969. 880 Concourse Pkwy., Suite 200,
# Birmingham (35244), 1330 Noble St. Suite 40 Radio Bldg.
# Mooresville (36202), (256) 237-8651. (205) 403-3340. Fax: (205)
# 403-3329. Web Site: ww.abe3340.com. Licensee: TV Alabama Inc.
# Group owner: Allbritton Communications Co, (acq 1-24-00) ¢Net:
# ABC Rep: Katz Radio Wash atty: Haley, Bader & Potts. News statf: 16;
# news progmg 9 hrs wkly, ¢Frank Dibillio, gen mgr, Gary Watkins,
# chief of engrg. ¢On 28 CATVs—73,437 subs. + Rates: $500; 90: 50.
#
# Bessemer
#
# DMA No. 51; see Birmingham (Anniston,
# Tuscaloosa), AL market
#
# WOBB—ch 17, 3,720 kw vis. 744 kw aur. 2.215i/2,000g. TL: N83 28
# 51 W87 24 03. (CP: 5,000 kw vis, ant 2,001t}. Hrs opn: 24. On air
# date: Oct 1. 1984. 651 Beacon Pkwy. W., Suite 105, Birmingham
# (85208). (205) 943-2188, Fax: (205) 290-2114. Licensee: WOBB-TV
# Inc, Ownership: Cecil Heftel; H. Carl Parmer; D&C L.L.C. (acq
# 1-19-95; $1.5 million) Rep: Adam Young Wash alty: Fleicher, Heald &
# Hildreth. News staff: 20; news progmg 15 hrs wkly, #Sandy Stewart,
# gen mgr, Marty Godsey, opns mgr: Margie Tramun, sls dir, Dawn
# Walker, mkig dir, adv dir & progmg dir; Tim Costley, engrg mgr & chief
# of engrg. ¢On 29 CATVs—108,419 subs.
#
# Birmingham
#
# DMA No. 51; see Birmingham (Anniston,
# Tuscaloosa), AL market
#
# WABM—ch 68, 1,442 kw vis, 144 kw aur. 1.0251, TL: N83 27 57 W865
# 47 45, (CP: 5,000 kw vis, ant 1,030L TL. N33 27 37 W86 51 07). Hrs
# opn: 24. On air date: January 1986, 651 Beacon Pkwy. W., Suite 105
# (35209), (205) 943-2168, Fax: (205) 290-2114, Web Site:
# wwW.wabm6B.com, Licensee: Birmingharn (WABM-TV) Licensee Ino.
# Group owner: Glencairn Lid. (acq 7-95: $4.5 million; FTR: 5-22-95)
# ¢Chris Hummel, CFO; Sandy Stewart. gen mgr; Deanna Goins, adv
# dir, John Batson. engrg dir, Tim Costley, chiet of engg #On 25
# CATVs—160,000 subs.
#
# “WBIOQ—ch 10, 316 kev vis, 31,6 kw aur, 1,325Y1,042g, TL: N3B29 19
# We6 47 58. On alr date: Apr 28, 1955. 2112 11th Ave. S., Sulte 400
# (35205). (205) 328-8756. Fax: (205) 251-2192. Web Site:
# wwwapivorg. Licensee: Alabama ETV Commission. «Net: PBS
# + Allan Pizzato, CEO; Dr. John Mosley, chm: Pauline Howland. CFO;
# Alan Pizzato. opns dir: Julia Fleming, dev cir Diana Pool. sls dir; Mike
# McKenzie, prom dir & adv dir, Jamie Lewis, progmg mgr: Jon Beans.
# news dir, Charlie Grantham, engrg dir
#
# WBRC—ch 6, 100 kw vis, 10 kw aur, 1,377/1.010g. TL: N33 29 19
# W86 47 58. (CP: Ant 1,086t). Hrs opm: 24. On air date: July 1, 1949.
# Box 6 (35201). 1720 Valley View Dr. Mooresville (35209). (205)
# 322-6666. Fax: (205) 583-4285 Web Site: www.wbre.com. Telex:
# 810-793-3650. Licensee; Fox Television Stations Inc. (group owner,
# acq 7-21-95) + Net; Fox Rep: TeleRep News staff: 53; news progmg
# 21 hrs wkly. *Dennis Lemon, gen mgr: Jerry Thom, chief of engrg.
# On 106 CATVs—517,986 subs,
#
# WIAT—ch 42, 2,163 kw vis. 216 kw aur. 1,382V/1,134g, TL: N33 29 02
# W286 48 21. (CP: 5,000 kw vis). On alr date: Oct 17, 1965. 2075
# Goldencrest Dr. (35209). (205) 322-4200. Fax: (205) 320-2722. Web
# Site: www.wiet.com. Licensee: Media General Communications Inc.
# Group owner: Media General Broadcast Group (acq 1997, grpsl).
# Net: CBS Rep: MMT Wash atty: Dow. Lohnes & Albertson. News
# staff: 70; news progmg 6 hrs wkiy. #4. D. Huey, pres; Tod Cucelt, gen
# mgr, Phil Smith, opns mgr; Susan P. Kelly, gen sls mgr; Doug Wilson.
# nail sls mgr: Todd Buccelli, mktg dir: Ted Putman. prom mgr: Larry
# Ragan, news dir; Fred Vincent, chief of engyg. #On 48 CATs,
#
# WTTO—th 21. 1,042 kw vis, 104.2 kw aur, 1,9420/1.058g, TL: N33 30
# 42 W86 48 24, (CP: 5,000 kw vis, ant 13408), On air date: Apr 21,
# 1982. 651 Beacon Pkwy. W., Suite 105, Huntsville (35209). (205)
# 943-2168. Fax, (205) 290-2114. Web Site: www.wtto21.com,
# Licensee: WTTO Licensee L.L.C. (acq 12-21-90) Rep: Katz Radio
# Wash atty: Arter & Hadden. #Chris Hummel, CFO; Sandy Stewart,
# gen mgr; Deanna Goins, prom dir & adv dir Tim Costley. engrg dir &
# chief of engrg. #On 90 CATVs—300,000 subs. On 62 trans,
#
# WVTW-TV—ch 13, 916 kw vis, 47.4 ker aur. 1,3400/1,078g. TL: N33 25
# 26 Wa6 47 48, On air date: May 1949, 1782 Vatley View Dr. (35209).
# (208) 588-7300 (news). Fax: (205) 933-7518 (sales). E-mail
# newscomments@nbc13.com. Web Site: www.nbe3.com. Licensee:
# Birmingham Broadcasting (WYTM-T¥) LLC, Group owner: NBC TV
# Stations Division (acq 1998; $425 million plus working capital with
# KNSD(TV San Diego. CA). # Net: NBC News staff: 70; news progmg
# 24 hrs wkly, #Dave Doebler, pres & gen mgr, Pete Hollenstein, sis
# VP; Philip Lozito, nall sls mgr; Kelly Dinkel, rgn\ sts mgr; Don Hofifield,
# prom dir; Tina Yarbrough. progmg dir; Yvette M. Miley, news dir; Chuck
# Blackwood, engrg dir. #On 175 CATVs—420,000 subs.
#
# Decatur
# WAFF—See Huntsville
# Demopolis
#
# DMA No. 113; see Montgomery (Selma), AL
# market
#
# “WIIQ—ch 41, 447 kw vis, 44.7 kw aur. 1,082/909g. TL: N32 22 01
# W87 52 03. On air date: Sept 13, 1971. 2112 11th Ave. S., Suite 400,
# Birmingham (35205-2884). (205) 328-8786. Fax: (205) 251-2192. Web
# Site: www.aptv.org. Licensee: Alabama ETV Commission. + Net: PBS
# «Judy Stone, CEO: Tony Jacobs, stn mar.
#
# *WIIQ-DT—ch 19. 50 kw vis. 1.027t. TL: N32 21 45 W87 52 04.Not on
# air, target date: unknown: 2112 11th Ave. S., Suite 400, Birmingham
# (35205-2884). (205) 328-8756, Fax: (205) 251-2192, Permitiee:
# Alabama Educational TV Commission. #Net: PBS ¢ Alan Pizzato,
# CEO.
#
# Dothan
# DMA No. 174; see Dothan, AL market
#
# WDHN—ch 18, 1.080.4 kw vis, 108 kw aur. 7301/7969. TL: N31 14 30
# WS 18 48, Hrs opn: 24. On air date: Aug 7, 1970. Box 6237 (36302)
# 5274 E. Hwy. 52, Webb (36302). (334) 793-1818. Fax: (334)
# 793-2623. Licensee: Morris Network of Alabama Inc. Group owner:
# Nexstar Broadcasting Group Inc. (acq 33-03: $40 million with
# KARK-TY Little Rock, AR). #Net. ABC Rep: Katz Radio Wash atty:
# Fletcher, Heald & Hildreth, News staff; 8; news proamg 7 hrs wkly.
# Mike Smith, VP & gen mgr: Janie Hinson, gen sis mgr, Mark
# Williams, prom dir, Tom Wall, progmg dir; Ken Curtis, news dir, Edna
# Darrow, pub affrs dir, Neal Riddle. chief of engrg. #On 26
# CATVs—55,000 subs.
#
# WTVY¥—ch 4, 100 kw vis, 20 kw aur. 1,6701/1,909g, TL: N30 55 10
# WAS 44 28, Hrs opn: 24. On air date: Feb 12, 1955. Box 1089 (36302).
# 285 N, Foster (36303), (334) 792-3195, Fax; (334) 793-3947. Web
# Site: www.wivynews4 com, Licensee: Gray MidAmerica TV Licensee
# Corp. Group owner: Gray Television Ine. (aeq 8-25-02: grpsl). «Net:
# CBS News staff: 18, news progmg 16 hrs wkly. ¢J. Mack Robinson,
# CEO & chmn; Robert S. Prather Jr., pres, Jim Ryan, CFO & sr VP,
# Hilton Howell, VP & sin mgr: Patrick Dalbey, gen mgr & progmg mgr
# Richard Morgan, gen sis mgr; Milicent Smith, natl sis mgr, Judy
# Calhoun, rgni sis mgr. Mike Doherty, prom dir, Al Roberts, news dir;
# Ann Varnum, pub affrs dir; Wade Thomaston, chief of engrg. ¢On 79
# CATVs—180.000 subs.
#
# Dozier
#
# DMA No. 113; see Montgomery (Selma), AL
# market
#
# *WOIG—ch 2, 100 kw vis, 10 kw aur. B951/566g. TL: N31 33 16 W86
# 23 32. On air date: Aug 8 1956. 2112 11th Ave. S., Suite 400,
#
# Broadcasting & Cable Yearbook 2003-2004
# B-3
#
# WWW.americanradiohistorv.com
#
# Birmingham (35205). (205) 328-8756. Fax: (205) 251-2192. Web Site:
# www.aptv.org. Licensee; Alabama ETV Commission. #Net: PBS
# Alan Pizzato, CEO.
#
# Florence
#
# DMA No. 81; see Huntsville-Decatur (Florence),
# AL market
#
# “WFIQ—ch 36, 589 kw vis, 58.9 kw aur. 760/538g. TL: N34 34 40
# W87 46 54, (CP; 1,276 kw vis), On air date: Aug 16, 1967. 2112 11th
# Avé, S., Suite 400, Birmingham (85205). (205) 328-8756, Fax: (205)
# 251-2192, Web Site: www.aptvorg. Licensee: Alabama ETV
# Commission. ¢ Net, PBS ¢ Alan Pizzato, CEO, Pauline Howlang. sin
# mgr.
#
# WHDF—ch 15, 1,410 kw vis, 400 kw aur. 730/562g. TL: N34 35 01
# W87 47 14. Hrs opn: 19. On air date: Oct 29, 1957. 840 Cypress Mill
# Rd. (35630-0220). (256) 767-1515, Fax: (256) 764-7750. Licensee:
# Valley Television LLC. Ownership: GBG LLC (acq 10-25-96; $2.4
# nillion). #Net NBC Rep: Roslin News staff: 9; news progmg 4 hrs
# wkly. # Gary Kneller, CEO & gen mgr. ¢On 29 CATVs—50,000 subs.
#
# WYLE—ch 26, 690 kw vis, 69 kw aur, 7561, TL: N34 34 38 W87 46
# 57. Hrs opn: 24. On air date: Apr 19, 1986. Box 850, 700 W.
# Montgomery Ave., Sheffield (35660), (256) 381-2600, Fax: (256)
# 389-3157. Licensee: ETC Communications Inc, Ownership: Les
# White, 100%. (aeg 6-93) News staf: 4; news progmig 5 hrs wkly, #Les
# White, CEO, gen mgr, film buyer & pub affrs dir; Terry Snead, sin mar;
# Ron Sauls, opns VP; Nick Scott, gen sis mgr & prom mgr; Karen
# ‘Snead, progmg dir; Frank Greene, news dir, Tim Rovere, engrg mgr.
# On 51 CATVs—193,000 subs, On one trans,
#
# Gadsden
#
# DMA No, 51; see Birmingham (Anniston,
# Tuscaloosa), AL market
#
# WPXH—ch 44, 1,750 kw vis, 175 kw aur. 1,0001/500g, TL: N33 57 11
# W86 13 00. (CP: 5,000 kw vis, ant 1.1151. TL: N33 53 27 W86 28 18).
# Hrs opn: 24. On air date: Apr 26, 1986. 2085 Goldencrest Dr.,
# Birmingham (35209), (205) 870-4404. Fax: (205) 870-0744. Licensee:
# Paxson Communications License Co. L.L.C. Group owner: Paxson
# Communications Corp. Wash atty: Fletcher, Heald & Hildreth. News
# progmg 8 irs wkly. ¢ Debra White Perry, gen mgr, opns mgr & progmng
# dir, Jim Moss, gen sis mgr; Angie Strawn, rgnl sls mgr, Deanine
# Thrash. prom mgr; Terreil Smith, chief of engrg. On 30
# CATVs--100,000 subs.
#
# WPXH-DT—ch 45, 225 kw vis, 1,063, TL: N33 53 27 W865 28 13.Not
# ‘on air, target date: unknown: 2085 Goldencrest Dr., Birmingham
# (35209). (205) 870-4404. Fax: (205) 870-0744. Permittee: Paxson
# Communications License Co. LLC. Group owner: Paxson
# Communications Corp. + Debra White Perry, gen mgr.
#
# WTUP—ch 60, 5.000 kw vis, 500 kw aur. 1,139! TL: N33 48 53 Wa6
# 26 55. On air date: July 22, 1986. 313 Rosedale Ave. (35901-5361).
# (256) 546-8860. Fax: (256) 543-8623. Web Site: www.tbn.org
# Licensee: Trinity Christian Center of Santa Ana Inc. dba Trinity
# Broadcasting Network. Group owner: Trinity Broadcasting Network
# (acg 5-8-00) #Paul F. Crouch, CEO & pres; Terry Hickey, exec VP:
# Gary Hodges, gen mgr & gen s's mgr; Curtiss Kemp, chief of engrg.
# On 15 CATVs—60,000 subs.
#
# Gulf Shores
#
# DMA No. 61; see Mobile, AL-Pensacola (Ft.
# Walton Beach), FL market
#
# WBPG—ch 55, 1510 kw vis, ant 1,010t, TL: N30 36 37 W87 36 26.
# ‘On air date: Sept 1, 2001. 1501 Satchel Paige Dr., Mobile (36606).
# (251) 434-1010, Fax; (251) 434-1073, Web Site: www.ounwbSs.tv,
# Licensee; Emmis Television License Com. Group owner: Emmis
# Communications Corp, (acq 3-1-03; $11.5 million). # Seatt Wilson, VP
# & gen mgr.
#
# Huntsville
#
# DMA No. 81; see Huntsville-Decatur (Florence),
# AL market

# %%
with open("sample.json", "w") as outfile: 
    json.dump(result, outfile)
